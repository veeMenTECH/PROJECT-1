# %% [markdown]
# # Name : Vera Mensah Aborah
# # ID Number : 10958719
# # Programme :Biomedical Engineering
# # Project: PYTHON DATA ANALYSIS

# %%
import pandas as pd

# %%
import numpy as num

# %%
import matplotlib.pyplot as plot

# %%
import seaborn as sbn

# %%
data = pd.read_csv('data.csv')

# %% [markdown]
# # DATA REVIEW

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB
# None

# %% [markdown]
# # CROSS-CHECKING FOR NULL CELLS

# %%
print(data.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# # CROSS-CHECKING FOR DUPLICATE NUMBERS

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Correcting null cells by filling them with mean values
# #### This is to ensure that data is not lost since it's always best to keep data rather than deleting it to prevent any form of misfortune from happening.
# #### Hence, the null cells are filled with mean of all values in oder to establish a correlation with existing data in the cells

# %%
everyColumn = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides','free sulfur dioxide', 'total sulfur dioxide','density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
for column in everyColumn:
    data[column].fillna(data[column].mean(), inplace=True)

# %% [markdown]
# # Comfirming existence of Null Values

# %%
print(data.isnull().sum())
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# # SKETCHING OF STATISTICAL DEDUCTIONS FOR ENTIRE DATASET AND COLUMNS
#
# ## HISTOGRAM FOR EVERY COLUMN

# %%
IDs= data.drop('ID', axis = 1)
IDs.hist(figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %% [markdown]
# # A LINE GRAPH DEMONSTRATING THE QUALITY OF DATASET FOR EVERY COLUMN.

# %%
everyColumn = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides','free sulfur dioxide', 'total sulfur dioxide','density', 'pH', 'sulphates', 'alcohol']
plot.figure(figsize=(12,6))
for column in everyColumn:
    plot.title(f'Quality graph for {column}')
    sbn.lineplot(x='quality', y=column, data=data)
    plot.show()

# %% [markdown]
# #   RELATIONSHIP BETWEEN THE FIXED ACIDITY AND pH VALUES

# %%
acids = ['fixed acidity', 'citric acid', 'volatile acidity']

# %%
for acid in acids :
    plt.title(f'Relationship between {acid} and the pH')
    sns.scatterplot(x=acid, y = 'pH', data=data)
    plt.figure(figsize=(12,9))
    plt.show()

# %% [markdown]
# # USING A PIE CHART TO REPRESENT THE QUALITY VALUES

# %%
plot.figure(figsize=(9,7)) 
quality_vals = data['quality'].value_counts()
plot.pie(quality_vals.values, labels=quality_vals.index, autopct='%1.1f %%')
plot.title('Pie Chart of Quality')
plot.axis('equal')
plot.show() #use varying colours for this plot

# %% [markdown]
# # USING PAIRPLOT TO SHOW HIDDEN INFERENCES

# %%
sns.pairplot(data, vars = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides'])

# %% [markdown]
# # USING HEAT MAP FOR DATA CORRELATION BETWEEN INDIVIDUAL COLUMNS OF THE DATA

# %%
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True , cmap = 'hot')
plt.figure(figsize=(13,6))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
